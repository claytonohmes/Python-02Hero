# %% [markdown]
# # Section 7: Milestone project 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## displaying information

# %%
def display(row1,row2,row3):
    print(row1)
    print(row2)
    print(row3)

# %%
example_list= [1,2,3]

display(example_list,example_list,example_list)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
row1 = [' ',' ',' ']
row2 = [' ',' ',' ']
row3 = [' ',' ',' ']

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %% [markdown]
# ## Accepting User Input

# %%
result = input('Please enter a value: ')

# %%
result
# Out:
# '2'

# %%
int(result)
# Out:
# 2

# %%
position_index = int(input('Enter Value:'))

# %%
position_index
# Out:
# 3

# %% [markdown]
# ## Validating User input

# %%
def user_choice():
    choice = input("Please enter a number (0-10): ")

    return int(choice)

# %%
user_choice()
# Out:
# 11

# %%
def user_choice():

    choice = 'WRONG'
    while choice.isdigit() == False:
        choice = input("Please enter a number (0-10): ")

        if choice.isdigit() == False:
            print('what you entered as not a digit.')

    return int(choice)

# %%
user_choice()
# Out:
# what you entered as not a digit.
# what you entered as not a digit.
# what you entered as not a digit.
# what you entered as not a digit.
# what you entered as not a digit.
# what you entered as not a digit.
# 5

# %%
result = 'Wrong'

# %%
acceptableValues = [0,1,2,3]

# %%
result in acceptableValues
# Out:
# False

# %%
def user_choice():
    #initial
    choice = 'WRONG'
    acceptablerange = range(0,10)
    within_range = False

    #two conditions to check
    while choice.isdigit() == False or within_range == False:
        choice = input("Please enter a number (0-10): ")
        #digit check
        if choice.isdigit() == False:
            print('what you entered as not a digit.')

        if choice.isdigit() == True:
            if int(choice) in acceptablerange:
                within_range = True
            else:
                print('out of range.')
                within_range = False

    return int(choice)

# %%
user_choice()
# Out:
# what you entered as not a digit.
# what you entered as not a digit.
# out of range.
# out of range.
# out of range.
# 2

# %% [markdown]
# ## Simple User Interaction

# %%
game_list = [0,1,2]

# %%
def display_game(game_list):
    print('Here is the current list: ')
    print(game_list)

# %%
display_game(game_list)
# Out:
# Here is the current list:
# [0, 1, 2]

# %%
def position_choice():
    choice = 'Wrong'
    while choice not in ['0','1','2']:
        choice = input('Pick a position (0,1,2): ')

        if choice not in ['0','1','2']:
            print('sorry, invalid choice!')

    return int(choice)

# %%
position_choice()
# Out:
# sorry, invalid choice!
# sorry, invalid choice!
# 2

# %%
def replacement_choice(game_list,position):
    user_placement = input('Type a string to place at position: ')

    game_list[position] = user_placement

    return game_list

# %%
replacement_choice(game_list,1)
# Out:
# [0, 'new', 2]

# %%
def game_on_choice():
    choice = 'Wrong'
    while choice not in ['Y','N']:
        choice = input('Keep Playing? (Y,N): ')

        if choice not in ['Y','N']:
            print('sorry, invalid choice!')

    if choice == 'Y':
        return True
    else:
        return False

# %%
game_on = True
game_list = [0,1,2]

while game_on:

    display_game(game_list)

    position = position_choice()

    game_list = replacement_choice(game_list,position)

    game_on = game_on_choice()
# Out:
# Here is the current list:
# [0, 1, 2]
# sorry, invalid choice!
# Here is the current list:
# [0, 1, 'hi']
# Here is the current list:
# [0, 'hi', 'hi']
# sorry, invalid choice!
