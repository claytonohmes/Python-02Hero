# %% [markdown]
# # Object Orientated Programming

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Let's check the syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# init method creates an instance of the object.

# %% [markdown]
# ## Attributes and class keyword

# %%
# The class keyword and creating attributes for our objects
mylist = [1,2,3]

# %%
myset = set()

# %%
type(myset)
# Out:
# set

# %% [markdown]
# by convention, camel casing for classes.

# %%
class SampleWord():
    pass

# %%
my_sample = SampleWord()

# %%
type(my_sample)
# Out:
# __main__.SampleWord

# %%
class Dog():
    def __init__(self,mybreed,):
        # attributes
        # We take in the argument
        # assign it using self.attribute_name
        self.my_attribute = mybreed

# %%
my_dog = Dog()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 my_dog = Dog()
#
# TypeError: Dog.__init__() missing 1 required positional argument: 'mybreed'

# %%
my_dog = Dog(mybreed='Huskie')

# %%
my_dog.my_attribute
# Out:
# 'Huskie'

# %% [markdown]
# conventially, all three terms will be the same...

# %%
class Dog():
    #class object attribute
    #same for any instance of a class
    species = 'mammal'

    def __init__(self,breed,name,spots):
        # user defined attributes
        # We take in the argument
        # assign it using self.attribute_name
        self.breed = breed
        self.name = name
        #boolean True or false
        self.spots = spots

# %%
my_dog = Dog(breed='Lab',name='Sammy',spots=True)

# %%
print(my_dog.spots)
print(my_dog.name)
print(my_dog.breed)
print(my_dog.species)
# Out:
# True
# Sammy
# Lab
# mammal

# %% [markdown]
# ## Methods in the class

# %%
class Dog():
    #class object attribute
    #same for any instance of a class
    species = 'mammal'

    def __init__(self,breed,name,spots):
        # user defined attributes
        # We take in the argument
        # assign it using self.attribute_name
        self.breed = breed
        self.name = name
        #boolean True or false
        self.spots = spots

    #operations/actions ---> Methods
    def bark(self, number):
        #you need to always bind the attributes to self when referencing them in operations/methods
        print('woof My name is {} and the number is {}'.format(self.name,number))

# %%
my_dog = Dog(breed='Lab',name='Sammy',spots=True)

# %%
my_dog.bark(7)
# Out:
# woof My name is Sammy and the number is 7

# %%
class circle():

    #class object attribute
    pi = 3.14

    def __init__(self,radius=1) -> None:
        self.radius = radius
        # you can reference CLASS OBJECT ATTRIBUTES as the class name instead of self
        self.area = radius * radius * circle.pi

    def get_circumference(self):
        return self.radius * self.pi * 2

# %%
my_circle = circle(30)

# %%
my_circle.pi
# Out:
# 3.14

# %%
my_circle.radius
# Out:
# 30

# %%
my_circle.area
# Out:
# 2826.0

# %%
my_circle.get_circumference()
# Out:
# 188.4

# %% [markdown]
# ## Inheritence and Polymorphism

# %%
class Animal():
    
    def __init__(self):
        print('Animal Created')

    def who_am_i(self):
        print('I am an animal')
    
    def eat(self):
        print('I am eating')

# %%
class Dog(Animal):

    def __init__(self):
        Animal.__init__(self)
        print('dog created.')

    def who_am_i(self):
        print('i am a dog')
    
    def bark(self):
        print('woof')

# %%
mydog = Dog()
# Out:
# Animal Created
# dog created.

# %%
mydog.eat()
# Out:
# I am eating

# %%
mydog.who_am_i()
# Out:
# i am a dog

# %% [markdown]
# ## polymorphism

# %%
class Dog():
    def __init__(self,name):
        self.name = name

    def speak(self):
        return self.name + ' Says woof'

# %%
class Cat():
    def __init__(self,name):
        self.name = name

    def speak(self):
        return self.name + ' Says Meow'

# %%
niko = Dog('niko')
felix = Cat('Felix')

# %%
print(niko.speak())
print(felix.speak())
# Out:
# niko Says woof
# Felix Says Meow
