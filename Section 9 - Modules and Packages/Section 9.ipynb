# %% [markdown]
# # Modules and Packages

# %% [markdown]
# ## Pip install and PyPi

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# when a python program runs, everything at indentation level 0 runs first
