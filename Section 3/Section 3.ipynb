# %%
my_list = [1,2,3]

# %%
my_list = ['STRING',20,50]

# %%
len(my_list)
# Out:
# 3

# %%
my_list[0]
# Out:
# 'STRING'

# %% [markdown]
# You can use slicers with a list to output all objects after a certain index.

# %%
my_list[1:]
# Out:
# [20, 50]

# %%
mylist = ['one','two','three']

# %%
another_list = ['four','five']

# %%
mylist + another_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
newlist = mylist + another_list

# %%
newlist
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
newlist[0] = 'ONE ALL CAPS'

# %%
newlist
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
newlist.append('six')

# %%
newlist
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
newlist.append('seven')

# %% [markdown]
# The pop method will by default remove the last item from a list. (index position -1)

# %%
newlist.pop()
# Out:
# 'seven'

# %%
newlist
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
popped_item = newlist.pop()

# %%
popped_item
# Out:
# 'six'

# %%
newlist.pop(0)
# Out:
# 'ONE ALL CAPS'

# %%
new_list = ['a','e','x','b','c']
num_list = [4,1,8,3]

# %% [markdown]
# The sort method occurs in place! It returns a None object!

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list
# Out:
# [4, 1, 8, 3]

# %%
num_list.sort()
num_list
# Out:
# [1, 3, 4, 8]

# %%
num_list.reverse()
num_list
# Out:
# [1, 3, 4, 8]

# %%
my_dict = {'key1':'value1','key2':'value2'}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %% [markdown]
# A very good example of when you might want to use a dictionary as your data structure is a database of prices.

# %%
price_lookup = {'apple':2.99,'oranges':1.99,'milk':5.80}

# %%
price_lookup['apple']
# Out:
# 2.99

# %%
d = {'k1':123,'k2':[0,1,2],'k3':{'insideKey':100}}

# %%
d['k3']['insideKey']
# Out:
# 100

# %%
d['k2']
# Out:
# [0, 1, 2]

# %%
d['k2'][2]
# Out:
# 2

# %%
d = {'key1':['a','b','c']}

# %%
d['key1']
# Out:
# ['a', 'b', 'c']

# %%
d['key1'][2].upper()
# Out:
# 'C'

# %%
d = {'k1':100,'k2':200,'k3':300}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values([100, 200, 300])

# %%
d.items()
# Out:
# dict_items([('k1', 100), ('k2', 200), ('k3', 300)])

# %% [markdown]
# ### I/O with basic files in python

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# g:\My Drive\Learning\Udemy\PythonZ2H\Claytons Notebooks

# %% [markdown]
# This is how you set a variable equal to the text of a file.

# %%
myfile = open('Section3IO.txt')

# %% [markdown]
# print the working directory.

# %%
pwd # type: ignore
# Out:
# 'g:\\My Drive\\Learning\\Udemy\\PythonZ2H\\Claytons Notebooks'

# %% [markdown]
# Reversing a string cuz that's sick

# %%
string1 = 'Hello'
string1[::-1]
# Out:
# 'olleH'

# %%
myfile.read()
# Out:
# ''

# %% [markdown]
# Think of there being a cursor in the file. the seek method puts that cursor back to the beginning

# %%
myfile.seek(0)
# Out:
# 0

# %%
contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line'

# %%
myfile.seek(0)
# Out:
# 0

# %% [markdown]
# Readlines creates a list with each element representing a line.

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n',
#  'this is the second line\n',
#  'this is the third line']

# %% [markdown]
# if you want to open files at another location on your computer, you simply need to provide the full file path.

# %% [markdown]
# best practices for opening files.
# you need to use .close()

# %%
with open('Section3IO.txt') as my_new_file:
    contents = my_new_file.read()

contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('myfile.txt',mode='w+') as myfile:
    contents = myfile.read()

# %%
# %%writefile my_new_file.txt
# one on first
# two on second
# three on third
# Out:
# Writing my_new_file.txt

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# one on first
# two on second
# three on third

# %%
with open('my_new_file.txt',mode='a') as f:
    f.write('Four on fourth')

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# one on first
# two on second
# three on third
# Four on fourth

# %%
with open('asdhjfasjdhf.txt',mode='w') as f:
    f.write('I created this file.')

# %% [markdown]
# Resources for More Basic Practice
# Before you begin your assessment, I wanted to point out some helpful links for practice (don't worry about being able to do these exercises, I just want you to be aware of the links so you can visit them later, since we still haven't discussed functions, you won't be able to utilize a lot of these resources yet!):
#
# Basic Practice:
#
# http://codingbat.com/python
#
# More Mathematical (and Harder) Practice:
#
# https://projecteuler.net/archives
#
# List of Practice Problems:
#
# http://www.codeabbey.com/index/task_list
#
# A SubReddit Devoted to Daily Practice Problems:
#
# https://www.reddit.com/r/dailyprogrammer
#
# A very tricky website with very few hints and touch problems (Not for beginners but still interesting)
#
# http://www.pythonchallenge.com/
